# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Trial-Duration" data-toc-modified-id="Trial-Duration-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Trial Duration</a></div><div class="lev1 toc-item"><a href="#Intertrial-Interval" data-toc-modified-id="Intertrial-Interval-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Intertrial Interval</a></div>

# %%
# Data manipulation
import numpy as np
import pandas as pd

# Plotting
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# spikelearn
import os
os.chdir('../../')
import sys
sys.path.append('.')

from spikelearn.data import io
from spikelearn.data.selection import select
from spikelearn.visuals.visuals import raster_multiple, raster_plot

# %%
# Definitions
DRRD_RATS = ['DRRD 7','DRRD 8','DRRD 9','DRRD 10']
AUTOSHAPE_RATS = ['Autoshape 7','Autoshape 8','Autoshape 9','Autoshape 10']
ALL_RATS = DRRD_RATS + AUTOSHAPE_RATS

# Facilitators
BASE_FIG_SIZE = np.array([20, 4])
mpl.rc("figure", figsize=BASE_FIG_SIZE)
per_rat_plot = lambda nplots, rats: plt.subplots(nplots, len(rats), sharey=True, figsize=BASE_FIG_SIZE*[1, nplots])
# example: fig, axes = per_rat_plot(4)

# %% [markdown]
# # Trial Duration

# %% [markdown]
# # Intertrial Interval

# %%
bhv = {}
for label in ALL_RATS:
    bhv[label] = io.load(label, 'behavior')

# %%
rat = 'DRRD 7'
bhv[rat]['Intertrial Interval'] = np.hstack((0,bhv[rat].onset.values[1:]-bhv[rat].offset.values[:-1]))
bhv[rat]['Intertrial Interval'].plot()

# %%
rat = 'DRRD 8'
bhv[rat]['Intertrial Interval'] = np.hstack((0,bhv[rat].onset.values[1:]-bhv[rat].offset.values[:-1]))
bhv[rat]['Intertrial Interval'].plot()

# %%
rat = 'DRRD 9'
bhv[rat]['Intertrial Interval'] = np.hstack((0,bhv[rat].onset.values[1:]-bhv[rat].offset.values[:-1]))
bhv[rat]['Intertrial Interval'].plot()

# %%
rat = 'DRRD 10'
bhv[rat]['Intertrial Interval'] = np.hstack((0,bhv[rat].onset.values[1:]-bhv[rat].offset.values[:-1]))
bhv[rat]['Intertrial Interval'].plot()
